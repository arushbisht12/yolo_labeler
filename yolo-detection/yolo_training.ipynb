# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
import torch
import torchvision

# %%
print(f"Version: {torch.__version__}, GPU: {torch.cuda.is_available()}, NUM_GPU: {torch.cuda.device_count()}")
print(torchvision.__version__)
print(torch.__version__)

device = 'cpu'
if torch.cuda.is_available():
    device = '0'

print(os.getcwd())
# Out:
# Version: 2.10.0+cpu, GPU: False, NUM_GPU: 0
# 0.25.0+cpu
# 2.10.0+cpu
# c:\Coursework\ECE 148\yolo_labeler\yolo-detection

# %%
# To start from new model:
model = YOLO("yolo11n.pt")

# To continue training from a previous model: place in this directory, then:
# model = YOLO("best.pt")

# YOLO automatically handles your 16:9 images by adding gray padding
# to make them square during training. This is the most stable method.
model.train(
    data="data.yaml",
    epochs=2,
    imgsz=320,       # Standard training size (Higher res = better detection)
    batch=16,
    workers=4,       # Increase for better performance but higher RAM use
    name='oakd_lite_model',
    device=device,        # Use '0' for GPU, 'cpu' for CPU
    lr0=0.005,       # new settings applied from here
    resume=False,    # False = new settings, True = exact same settings
    copy_paste=0.2,
    scale=0.6,
    translate=0.2,
    hsv_s=0.7,
    hsv_v=0.4,
    erasing=0.3,
    save_period=50,
    patience=0
)


metrics = model.val()
# Out:
# New https://pypi.org/project/ultralytics/8.4.21 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.14  Python-3.12.0 torch-2.10.0+cpu CPU (AMD Ryzen 7 7840U w/ Radeon 780M Graphics)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.2, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=2, erasing=0.3, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=320, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.005, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=oakd_lite_model3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=0, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\jacky\runs\detect\oakd_lite_model3, save_frames=False, save_json=False, save_period=50, save_txt=False, scale=0.6, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.2, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access  (ping: 0.00.0 ms, read: 1875.1434.6 MB/s, size: 3879.6 KB)
# train: Scanning C:\Coursework\ECE 148\yolo_labeler\yolo-detection\dataset\labels\train.cache... 474 images, 0 backgrounds, 6 corrupt: 100% ━━━━━━━━━━━━ 474/474  0.0s
# train: C:\Coursework\ECE 148\yolo_labeler\yolo-detection\dataset\images\train\team10_image103.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0103]
# train: C:\Coursework\ECE 148\yolo_labeler\yolo-detection\dataset\images\train\team10_image105.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0303]
# train: C:\Coursework\ECE 148\yolo_labeler\yolo-detection\dataset\images\train\team10_image142.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0176]
# train: C:\Coursework\ECE 148\yolo_labeler\yolo-detection\dataset\images\train\team10_image36.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0194]
# train: C:\Coursework\ECE 148\yolo_labeler\yolo-detection\dataset\images\train\team10_image45.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0686]
# train: C:\Coursework\ECE 148\yolo_labeler\yolo-detection\dataset\images\train\team10_image75.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0103]
# val: Fast image access  (ping: 0.10.0 ms, read: 1914.4175.4 MB/s, size: 5753.1 KB)
# val: Scanning C:\Coursework\ECE 148\yolo_labeler\yolo-detection\dataset\labels\val.cache... 90 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 90/90  0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.005' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to C:\Users\jacky\runs\detect\oakd_lite_model3\labels.jpg...
# Image sizes 320 train, 320 val
# Using 0 dataloader workers
# Logging results to C:\Users\jacky\runs\detect\oakd_lite_model3
# Starting training for 2 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/2         0G      1.313      2.204      1.224          9        320: 100% ━━━━━━━━━━━━ 30/30 1.5s/it 46.4s1.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.2s/it 6.5s4.2ss
#                    all         90         90      0.943      0.555      0.761      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/2         0G      1.215       1.11      1.209          6        320: 100% ━━━━━━━━━━━━ 30/30 1.5s/it 45.1s0.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0s/it 6.1s4.0ss
#                    all         90         90          1      0.718      0.993      0.647
#
# 2 epochs completed in 0.029 hours.
# Optimizer stripped from C:\Users\jacky\runs\detect\oakd_lite_model3\weights\last.pt, 5.4MB
# Optimizer stripped from C:\Users\jacky\runs\detect\oakd_lite_model3\weights\best.pt, 5.4MB
#
# Validating C:\Users\jacky\runs\detect\oakd_lite_model3\weights\best.pt...
# Ultralytics 8.4.14  Python-3.12.0 torch-2.10.0+cpu CPU (AMD Ryzen 7 7840U w/ Radeon 780M Graphics)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.1s/it 6.2s4.1ss
#                    all         90         90          1      0.717      0.993      0.647
# Speed: 0.2ms preprocess, 8.3ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to C:\Users\jacky\runs\detect\oakd_lite_model3
# Ultralytics 8.4.14  Python-3.12.0 torch-2.10.0+cpu CPU (AMD Ryzen 7 7840U w/ Radeon 780M Graphics)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 2815.7535.9 MB/s, size: 5703.9 KB)
# val: Scanning C:\Coursework\ECE 148\yolo_labeler\yolo-detection\dataset\labels\val.cache... 90 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 90/90  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.0it/s 6.0s1.2ss
#                    all         90         90          1      0.717      0.993      0.647
# Speed: 0.1ms preprocess, 7.2ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to C:\Users\jacky\runs\detect\val

# %%
model.save("model.pt")
# model.export(format="onnx", imgsz=[320, 192], opset=12)
